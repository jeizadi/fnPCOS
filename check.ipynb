# %%
from garmindb import GarminConnectConfigManager
import os

# Check config loads correctly
config = GarminConnectConfigManager()
print("Config loaded:", config)

# Check the DB directory exists and has files
db_dir = os.path.expanduser('~/HealthData/DBs')
print("\nDB directory exists:", os.path.exists(db_dir))

if os.path.exists(db_dir):
    files = os.listdir(db_dir)
    print("DB files found:", files)
# Out:
# Config loaded: <garmindb.garmin_connect_config_manager.GarminConnectConfigManager object at 0x11417d400>
#
# DB directory exists: True
# DB files found: ['garmin_monitoring.db', 'summary.db', 'garmin_activities.db', 'garmin_summary.db', 'garmin.db']
